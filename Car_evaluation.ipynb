# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
url ="/content/drive/MyDrive/car_evaluation.csv"
df=pd.read_csv(url)

# %%
df
# Out:
#      Buying Price Maintenance Cost Number of Doors  ... lug_boot Safety Decision
# 0           vhigh            vhigh               2  ...    small    low    unacc
# 1           vhigh            vhigh               2  ...    small    med    unacc
# 2           vhigh            vhigh               2  ...    small   high    unacc
# 3           vhigh            vhigh               2  ...      med    low    unacc
# 4           vhigh            vhigh               2  ...      med    med    unacc
# ...           ...              ...             ...  ...      ...    ...      ...
# 1723          low              low           5more  ...      med    med     good
# 1724          low              low           5more  ...      med   high    vgood
# 1725          low              low           5more  ...      big    low    unacc
# 1726          low              low           5more  ...      big    med     good
# 1727          low              low           5more  ...      big   high    vgood
#
# ...

# %%
df.isnull().sum()
# Out:
# Buying Price         0
# Maintenance Cost     0
# Number of Doors      0
# Number of Persons    0
# lug_boot             0
# Safety               0
# Decision             0
# dtype: int64

# %%
import numpy as np

# %%
 import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df["Buying Price"])
# Out:
# (array([432.,   0.,   0., 432.,   0.,   0., 432.,   0.,   0., 432.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df["Decision"])
# Out:
# (array([1210.,    0.,    0.,  384.,    0.,    0.,   65.,    0.,    0.,
#           69.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
plt.bar(df["Maintenance Cost"],df["Number of Persons"])
# Out:
# <BarContainer object of 1728 artists>

# %%
import scipy
import seaborn as sns

# %%
sns.countplot(df['Safety'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df["Buying Price"].unique()
# Out:
# array(['vhigh', 'high', 'med', 'low'], dtype=object)

# %%
df["Number of Doors"].unique()
# Out:
# array(['2', '3', '4', '5more'], dtype=object)

# %%
df["Number of Doors"].replace(("2","4","5more"),(2,4,6),inplace=True)
df["Number of Doors"].unique
# Out:
# <bound method Series.unique of 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1723    6
# 1724    6
# 1725    6
# 1726    6
# 1727    6
# Name: Number of Doors, Length: 1728, dtype: object>

# %%
df["Number of Persons"].unique()
# Out:
# array(['2', '4', 'more'], dtype=object)

# %%
df["Number of Persons"].replace(("2","4","more"),(2,4,6),inplace=True)
df["Number of Persons"].unique
# Out:
# <bound method Series.unique of 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1723    6
# 1724    6
# 1725    6
# 1726    6
# 1727    6
# Name: Number of Persons, Length: 1728, dtype: int64>

# %%
sns.stripplot(df["Number of Doors"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(df["Number of Doors"],df["Number of Persons"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(df["Number of Persons"],df["Buying Price"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(df["Number of Persons"],df["Maintenance Cost"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(df["Number of Persons"],df["lug_boot"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(df["Number of Persons"],df["Safety"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(df["Number of Persons"],df["Decision"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.swarmplot(df["Decision"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 92.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
